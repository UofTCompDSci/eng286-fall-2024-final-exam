# %% [markdown]
# <div style="text-align: center">
#
# **UNIVERSITY OF TORONTO**
#
# **Faculty of Arts & Science**
#
# **FALL 2024 EXAMINATIONS**
#
# **ENG286H1F - Literature and Data**
#
# **Duration**: 3 hours
#
# **Aids Allowed**: You may access all course resources on JupyterHub, and MarkUs, including Melanie Welsh’s textbook *Introduction to Cultural Analytics & Python*. You are also permitted to consult any printed or handwritten materials that you have personally prepared before the exam. You may not consult any other references.
#
# </div>
#
# ## Exam Reminders
#
# - As a student, you help create a fair and inclusive writing environment. If you possess an
# unauthorized aid during an exam, you may be charged with an academic offence.
# - Turn off (completely power off) and place all cell phones, smart watches, electronic devices, and unauthorized study materials in your bag under your desk. If it is left in your pocket, it may be an academic offence.
# - When you are done your exam, download the file and submit it to [MarkUs](https://markus.teach.cs.toronto.edu/markus) under the `final_exam` assignment. We have included submission instructions at the bottom of this notebook (same as past course work). Please ensure that the file is labeled as **final_exam.ipynb**
# - All answers should be written in the provided cells in this notebook. You will *only* submit this notebook on MarkUs.
#
# **Note**: *We strongly encourage you to submit your in-progress version on MarkUs after each section. You should also give yourself at least 15 minutes at the end of the exam period to ensure you have downloaded and uploaded your exam file correctly.*
#
# ## Quick Links
#
# - [MarkUs](https://markus.teach.cs.toronto.edu/markus)
# - [JupyterHub home page](https://jupyter.utoronto.ca)
# - [Melanie Walsh Cultural Analytics](https://melaniewalsh.github.io/Intro-Cultural-Analytics/welcome.html)
# - [Lecture Slides and Course Readings](https://eng286.teach.cs.toronto.edu/)
#
# ## Overview
# The exam has 3 parts, each should take roughly an hour.
#
# - Part 1: Coding Exercises (16 points)
# - Part 2: Code Rationale (14 points)
# - Part 3: Essay (15 points)
#
# The exam is out of 45 points.

# %% [markdown]
# # Part 1: Coding Exercises (16 points, ~60 minutes)
#
# Part 1 of the exam asks you to perform a variety of coding tasks.

# %% [markdown]
# ## Task 1A (2 points)
#
# You are given a list of sentences in a varaible named `negation_sentences`. Your task is to
#
# - Create an empty list called `negation_word_count`.
# - Use a for loop to iterate through each item in `negation_sentences`.
# - Within the for loop, calculate the number of words in each sentence and append it to the `negation_word_count` list. For the purposes of coding, words in a sentence are separated by spaces, so a contraction is a word.  (Hint: the first element of `negation_word_count` should be 4.)

# %%
negation_sentences = ["I don't hate it",
 "This isn't the worst thing I've seen",
 "Can't complain about this service",
 'No one can deny that this works great',
 'Never been disappointed by their products',
 "Not exactly what I wouldn't recommend",
 "Couldn't be more unlike the terrible service elsewhere"]

 # Add your code here

# %%
#check your work
print(negation_word_count)

# %% [markdown]
# ## Task 1B (4 points)
#
# In the cell below, we created a dictionary using `negation_sentences` as the keys and `negations_wc_result` as the values. (`negations_wc_result`is the result of Task 1A, but to keep questions independent we reproduce it here.)
#
# We will define a _long_ sentence as one with more than 6 words.
#
# For each _long_ sentence, print the sentence and its length using the following template: `f"Sentence '{sentence_here}' is a long sentence. It contains {n} words"`, where `sentence_here` is a variable containing a sentence that is a _key_ in `negations` and `n` is a variable that contains the _value_ associated with the _key_.
#
# Hint:
# Use a for loop to iterate through each _key_ in negations.
# Within the loop, check the number of words in the value corresponding to the _key_. Use conditionals (`if` ... `elif` ... `else`).

# %%
# negation_wc_result contains the results of Task 1A
negation_wc_result = [4, 7, 5, 8, 6, 6, 8]
negations = dict(zip(negation_sentences, negation_wc_result))
print(negations) # Look at the results to understand the format

# Recall how to access a value of a dictionary using a key
print(negations["I don't hate it"]) # prints 4

# Here is a print statement you can use:
# print(f"Sentence '{sentence_here}' is a long sentence. It contains {n} words")
# Add your code below

# %%
# You should see a sequence of lines like this:
# Sentence 'I don't hate it' is a long sentence. It contains 4 words

# %% [markdown]
# ## Task 2A (2 points)
# The file `negations_polarity.csv` contains the results of sentiment analysis using TextBlob and Vader. The next cell reads the csv file into a dataframe called `negations_polarity`.
#
# Create a new column called `difference_detected` in the `negations_polarity` dataframe. The `difference_detected` column should be True if `textblob_sentiment` is not equal to `vader_sentiment` for a particular row and False otherwise. Hint: you don't need a loop.

# %%
import pandas as pd
negations_polarity = pd.read_csv('negations_polarity.csv')

# Add your code here

# %%
#check your work
print(negations_polarity.head())

# %% [markdown]
# ## Task 2B (2 points)
#
# Create a dataframe `negations_longer` containing ONLY the rows in `negations_polarity` where word_count > 6.

# %%
# Write your code here

# %%
#check your work
print(negations_longer)

# %% [markdown]
# ## Task 3A (3 points)
#
# First, run the cell below, which
# - Loads the libraries required for this exam, `TextBlob` and `pandas` and downloads the resources needed for `TextBlob` to work with words and sentences.
# - Uses the `open` function's `.read()` method to open a text file of text of Franz Kafka's *Metamorphosis* (`metamorphosis.txt`) with UTF-8 encoding, storing this in a string variable named `metamorphosis`.
# - Creates a TextBlob object of `metamorphosis` using the `TextBlob` function and stores it in a variable named `metamorphosis_blob`.
# - It also calls TextBlob's blob.sentences method on metamorphosis_blob and stores the output in a variable named metamorphosis_sentences_blob.
# - It creates `metamorphosis_sentences`, a list of strings produced using Python's `" ".join()` method to join (with spaces) the individual words in each sentence in *Metamorphosis*, as divided by TextBlob's `blob.sentences`
#
# **Your task is to create the following variable**:
#
# - `metamorphosis_polarities`: a list of floating point numbers, each containing (in order) the TextBlob sentiment polarity score for the sentences in *Metamorphosis*.

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt_tab')
import pandas as pd

metamorphosis = open("metamorphosis.txt", encoding="utf-8").read()

metamorphosis_blob = TextBlob(metamorphosis)
metamorphosis_sentences_blob = metamorphosis_blob.sentences

# Convert the TextBlob sentences to a list of strings
metamorphosis_sentences = []
for sentence in metamorphosis_sentences_blob:
    metamorphosis_sentences.append(" ".join(sentence.words))  

# Add your code here

# %%
#check your work
print(metamorphosis_polarities.head())

# %% [markdown]
# ## Task 3B (3 points)
#
# First, run the following code, which uses Pandas's `pd.DataFrame()` method to create a Pandas DataFrame named `metamorphosis_sentiment_df` with two columns:
# - `sentence`: The `sentence` column should contain the values from the `metamorphosis_sentences` variable created in task 3A
# - `polarity`: The `polarity` column should contain the values from the `metamorphosis_polarities` variable created in task 3A
#
#
# Then, **create the new DataFrame** `metamorphosis_top10_sentence_polarity` with the rows with the 10 highest polarity scores from the `metamorphosis_sentiment_df` dataframe found using the 'sort_values' function from the pandas library.

# %%
import pandas as pd

metamorphosis_sentiment_df = pd.DataFrame({
    'sentence': metamorphosis_sentences,
    'polarity': metamorphosis_polarities
})

# Add your code here

# %%
#check your work
print(metamorphosis_top10_sentence_polarity)

# %% [markdown]
# # Part 2: Code Rationale (14 points; ~50 minutes)
#
# This section consists of short answer questions checking your ability to interpret Python code and results. They can be related to the tasks from Part 1 or be standalone. Leave your written answers in the Markdown cells below each question. Write in full sentences.

# %% [markdown]
# ## Question 1 (2 points)
#
# What does Python's `.sort_values()` method from the pandas library do? What are we using it for in Task 3B above to create the `metamorphosis_top10_sentence_polarity` variable?

# %% [markdown]
# **(Delete this text and write your answer here.)**

# %% [markdown]
# ## Question 2 (4 points)
#
# Based on the table below, summarise the differences in how two sentiment analysis systems (vader and textblob) evaluate sentences with negations. First, discuss where and how they differ from each other. Then think about what sentiment would you assign to these sentences and evaluate both systems from that perspective.
#
# ||sentence|vader\_sentiment|vader\_polarity|textblob\_sentiment|textblob\_polarity|word\_count|
# |---|---|---|---|---|---|---|
# |0|I don't hate it|Positive|0\.4585|Negative|-0\.8|4|
# |1|This isn't the worst thing I've seen|Positive|0\.5096|Negative|-1\.0|7|
# |2|Can't complain about this service|Positive|0\.2755|Neutral|0\.0|5|
# |3|No one can deny that this works great|Positive|0\.128|Positive|0\.8|8|
# |4|Never been disappointed by their products|Positive|0\.3724|Negative|-0\.75|6|
# |5|Not exactly what I wouldn't recommend|Negative|-0\.2755|Negative|-0\.125|6|
# |6|Couldn't be more unlike the terrible service elsewhere|Negative|-0\.5209|Negative|-0\.25|8|

# %% [markdown]
# **(Delete this text and write your answer here.)**

# %% [markdown]
# ## Question 3 (4 points)
#
# Your professor returns a term test and reports to the class the mean grade is 70% and the median grade is median grade is 75%.  What do the mean and median tell us about the course grades?  What could it indicate if the median is higher than the mean?

# %% [markdown]
# **(Delete this text and write your answer here.)**

# %% [markdown]
# ## Question 4 (4 points)

# %% [markdown]
# ![rolling-averages-meta-10-25-50.png](data:image/png;base64,...)

# %% [markdown]
# The plot above shows rolling averages for the polarity for *Metamorphosis*.
#
# What is the difference between a rolling window of size 10, 25 and 50, according to the plot? Is one rolling window size preferred over the others with the *Metamorphosis* dataset? If so, why?

# %% [markdown]
# **(Delete this text and write your answer here.)**

# %% [markdown]
# # Part 3: Essay (15 points)
#
# Drawing on at least one course reading **and** at least one dataset discussed in lecture, write a short essay that responds to the following question:
#
# > **Does Data Science analysis of literary texts reveal anything new about them, or just confirm what we already know about them? What (if anything) do we gain from using computational tools to ask questions about literature and culture?**
#
# Write in paragraphs and full sentences. Do not use point form. A strong essay will:
#
# 1. have a clear argument (i.e., thesis statement);
# 2. be well organized; and
# 3. use specific examples to support its points.
#
# Aim for quality over quantity. We’ll be looking for a cohesive, focused piece of writing that draws on course materials to support its claim. You may want to take a few minutes to plan your approach before you begin writing, and don’t underestimate the power of well-crafted introductory and concluding paragraphs (however brief) that summarize your main ideas.

# %% [markdown]
# **(Delete this text and write your answer here.)**

# %% [markdown]
# ## How to Submit the Final Exam
#
# 1. Download this notebook to your computer and save it as `final_exam.ipynb`.
# 2. Log into MarkUs.
# 3. Submit the downloaded file to `final_exam: Final Exam`.
